# %% [markdown]
# ## Open API와 데이터 취급 포맷 이해와 활용
# 공공데이터
# JSON 포멧으로 제공됨
#
# 1. Open API이해
# 2. Open API쉽게 사용법
# 3. JSON 포멧 이해하기
# 4. 네이버 Open API 크롤링
# 5. 네이버 Open API활용, 네이버 쇼핑 엑셀 보고서 만들기
# 6. 정부 제공 공공 데이터 Open API사용법
# 7. XML 포멧 이해와 공공 데이터 Open API로 미세먼지 정보 크롤링

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import json

data = '''


{
    "lastBuildDate": "Thu, 06 May 2021 15:11:34 +0900",
    "total": 139695,
    "start": 1,
    "display": 10,
    "items": [
        {
            "title": "이테스트 프로페셔널스 시험 인기",
            "originallink": "http://www.inews24.com/view/1364731",
            "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=031&aid=0000597173",
            "description": "국가공인 민간자격시험인 이테스트는 <b>삼성 SDS</b>가 1989년에 만든 시험으로 파워포인트와 워드프로세스, 엑셀 등 OA(사무 자동화) 3개 과목으로 구성되어 있으며, 2014년 9월 (사)한국창의인성교육연구원으로 주관사가... ",
            "pubDate": "Thu, 06 May 2021 15:08:00 +0900"
        },
        {
            "title": "<b>삼성SDS</b>, 기업의 디지털 전환 수준 진단할 수 있는 서비스 내놔",
            "originallink": "https://www.businesspost.co.kr/BP?command=article_view&num=230270",
            "link": "https://www.businesspost.co.kr/BP?command=article_view&num=230270",
            "description": "<b>삼성SDS</b>가 기업의 디지털 전환 수준을 진단할 수 있는 서비스를 내놨다. <b>삼성SDS</b>는 기업의 디지털 전환 수준을 점검해 볼 수 있는 체험 서비스를 홈페이지 'My Trial' 코너에서 공개했다고 6일 밝혔다. 황성우 <b>삼성SDS</b>... ",
            "pubDate": "Thu, 06 May 2021 15:04:00 +0900"
        },
        {
            "title": "&quot;디지털 전환 수준 진단해보세요&quot; <b>삼성SDS</b>, 체험 서비스 오픈",
            "originallink": "http://news.mk.co.kr/newsRead.php?no=437419&year=2021",
            "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=105&oid=009&aid=0004790086",
            "description": "<b>삼성SDS</b>가 기업의 디지털 전환(DT) 수준을 진단할 수 있는 체험 서비스를 선보였다. 6일 <b>삼성SDS</b>는 기업의 DT 수준 진단 체험 서비스를 자사 홈페이지 마이 트라이얼(My Trial)코너에 공개했다고 밝혔다. 디지털... ",
            "pubDate": "Thu, 06 May 2021 14:58:00 +0900"
        },
        {
            "title": "“<b>삼성</b> 오너들의 상속구도는 <b>삼성</b>전자 지배력 유지에 최선책”",
            "originallink": "https://www.news2day.co.kr/article/20210506500219",
            "link": "https://www.news2day.co.kr/article/20210506500219",
            "description": "이 전 회장이 보유한 <b>삼성</b>전자(4.18%), <b>삼성</b>물산(2.9%), <b>삼성SDS</b>(0.01%) 등 다른 계열사들의 지분은 법정비율을 따라 상속됐다. 김장원 연구원은 “<b>삼성</b>전자의 지배구조가 <b>삼성</b>생명, <b>삼성</b>물산, 고(故) 이건희 회장에서 <b>삼성</b>생명... ",
            "pubDate": "Thu, 06 May 2021 14:54:00 +0900"
        },
        {
            "title": "<b>삼성SDS</b>, '디지털 전환' 진단 체험 서비스 오픈",
            "originallink": "http://www.sporbiz.co.kr/news/articleView.html?idxno=522712",
            "link": "http://www.sporbiz.co.kr/news/articleView.html?idxno=522712",
            "description": "삼성SDS 본사 전경 /<b>삼성SDS  삼성SDS</b>가 클라우드 기반 IT 솔루션 사업으로 고객의 디지털 전환(Digital Transformation)에 적극 나서고 있다. 삼성SDS는 AI‧데이터 분석·IoT·블록체인 등 신기술 플랫폼과 협업 및... ",
            "pubDate": "Thu, 06 May 2021 14:50:00 +0900"
        },
        {
            "title": "<b>삼성SDS</b>, 디지털 전환(DT) 수준 진단 체험 서비스 선보여",
            "originallink": "http://www.datanews.co.kr/news/article.html?no=112581",
            "link": "http://www.datanews.co.kr/news/article.html?no=112581",
            "description": "<b>삼성SDS</b>는 기업의 디지털 전환(DT) 수준을 진단할 수 있는 체험 서비스를 시작했다고 6일 밝혔다. <b>삼성SDS</b> 홈페이지의 ‘마이 트라이얼(My Trial)’ 코너에 마련된 이 서비스를 이용하면 디지털 전략 및 업무 프로세스, IT... ",
            "pubDate": "Thu, 06 May 2021 14:46:00 +0900"
        },
        {
            "title": "<b>삼성SDS</b>, 디지털전환(DT) 수준 점검 체험 서비스 오픈",
            "originallink": "https://www.dnews.co.kr/uhtml/view.jsp?idxno=202105061438000130079",
            "link": "https://www.dnews.co.kr/uhtml/view.jsp?idxno=202105061438000130079",
            "description": "<b>삼성SDS</b>가 6일 AI/데이터 분석·사물인터넷(IoT)·블록체인 등 신기술 플랫폼과 협업 및 업무자동화 등 클라우드 기반 솔루션(SaaS) 체험 서비스를 오픈했다. 이날 <b>삼성SDS</b>는 기업의 디지털 전환(DT) 수준 진단 체험... ",
            "pubDate": "Thu, 06 May 2021 14:42:00 +0900"
        },
        {
            "title": "<b>삼성SDS</b>, 기업 ‘디지털 전환 수준 진단’ 체험 서비스 오픈",
            "originallink": "http://moneys.mt.co.kr/news/mwView.php?no=2021050614348095365",
            "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=105&oid=417&aid=0000690559",
            "description": "<b>삼성SDS</b>는 기업이 자사 디지털 전환(DT) 수준을 진단할 수 있는 ‘마이 트라이얼(My Trial)’ 체험 서비스를 홈페이지를 통해 제공하고 있다고 6일 밝혔다. <b>삼성SDS</b>는 인공지능(AI)과 데이터 분석 및 사물인터넷(IoT)... ",
            "pubDate": "Thu, 06 May 2021 14:35:00 +0900"
        },
        {
            "title": "<b>삼성SDS</b>, 디지털 전환 수준 진단 체험 서비스 선봬",
            "originallink": "http://www.sportsseoul.com/news/read/1039323?ref=naver",
            "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=105&oid=468&aid=0000766339",
            "description": "기업·업종(제조) 등 5가지 분야 진단 가능 삼성SDS 잠실캠퍼스 전경.  제공 | <b>삼성SDS 삼성SDS</b>가 클라우드 기반 IT솔루션 사업을 앞세워 기업 고객의 디지털 전환(DT)에 적극 나서고 있다. 삼성SDS는 인공지능(AI)·데이터... ",
            "pubDate": "Thu, 06 May 2021 14:26:00 +0900"
        },
        {
            "title": "<b>삼성SDS</b>, 디지털 전환수준 진단 체험 서비스 오픈",
            "originallink": "http://www.smedaily.co.kr/news/articleView.html?idxno=203116",
            "link": "http://www.smedaily.co.kr/news/articleView.html?idxno=203116",
            "description": "사진/<b>삼성SDS 삼성SDS</b>가 클라우드 기반 IT 솔루션 사업으로 고객의 디지털 전환에 적극 나서고 있다. 삼성SDS는 AI·데이터 분석·IoT·블록체인 등 신기술 플랫폼과 협업 및 업무자동화 등 클라우드 기반 솔루션을... ",
            "pubDate": "Thu, 06 May 2021 14:24:00 +0900"
        }
    ]
}


'''

json_data = json.loads(data)

for i in range(10):

    print(json_data['items'][i]['title'])
    print(json_data['items'][i]['originallink'])
    print(json_data['items'][i]['link'])
    print(json_data['items'][i]['description'])
    print(json_data['items'][i]['pubDate'])
    i = i + 1 
    print("="*50)
# Out:
# 이테스트 프로페셔널스 시험 인기
# http://www.inews24.com/view/1364731
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=031&aid=0000597173
# 국가공인 민간자격시험인 이테스트는 <b>삼성 SDS</b>가 1989년에 만든 시험으로 파워포인트와 워드프로세스, 엑셀 등 OA(사무 자동화) 3개 과목으로 구성되어 있으며, 2014년 9월 (사)한국창의인성교육연구원으로 주관사가...
# Thu, 06 May 2021 15:08:00 +0900
# ...
# <b>삼성SDS</b>, 기업의 디지털 전환 수준 진단할 수 있는 서비스 내놔
# https://www.businesspost.co.kr/BP?command=article_view&num=230270
# https://www.businesspost.co.kr/BP?command=article_view&num=230270
# <b>삼성SDS</b>가 기업의 디지털 전환 수준을 진단할 수 있는 서비스를 내놨다. <b>삼성SDS</b>는 기업의 디지털 전환 수준을 점검해 볼 수 있는 체험 서비스를 홈페이지 'My Trial' 코너에서 공개했다고 6일 밝혔다. 황성우 <b>삼성SDS</b>...
# Thu, 06 May 2021 15:04:00 +0900
# ...
# &quot;디지털 전환 수준 진단해보세요&quot; <b>삼성SDS</b>, 체험 서비스 오픈
# http://news.mk.co.kr/newsRead.php?no=437419&year=2021
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=105&oid=009&aid=0004790086
# ...

# %%
import requests
import pprint 

client_id = 'v2rU3k_29grolRuMAxIl'
client_secret = 'AvOX6aVmqN'

naver_open_api = 'https://openapi.naver.com/v1/search/news.json?query=코딩&display=100&start=1'
header_params = {"X-Naver-Client-Id":client_id, "X-Naver-Client-Secret":client_secret}
res = requests.get(naver_open_api, headers = header_params)

if res.status_code == 200 :
    data = res.json()
    for index, item in enumerate(data['items']) :
        print(index + 1, item['title'], item['link'])
else : 
    print("Error Code:",res.status_code)
# Out:
# 1 서대문구, '가재울청소년센터' 4차 산업혁명 콘텐츠 특화공간 조성 https://www.iloveorganic.co.kr/news/articleView.html?idxno=324456
# 2 네이버제트 “‘제페토’에서 메타버스 함께 열자”..경력 채용 https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=105&oid=014&aid=0004634144
# 3 DGB대구은행, 특별 수시채용 실시…&quot;채용비리 피해자 구제&quot; http://www.newspim.com/news/view/20210506000859
# 4 DGB대구은행, 올 상반기 신입행원 특별 수시채용 https://news.bbsi.co.kr/news/articleView.html?idxno=3030842
# 5 LG화학, 농축협, 현대오토에버등 신입사원 채용 나서 http://www.kdpress.co.kr/news/articleView.html?idxno=102754
# 6 이테스트 프로페셔널스 시험 인기 https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=031&aid=0000597173
# 7 LG화학·한국콜마·현대오토에버 등 5월 신규 채용 http://www.skyedaily.com/news/news_view.html?ID=130472
# 8 제이와이네트워크 디자인, 온택트 시대 반응형 홈페이지와 웹사이트 제작으로... http://www.nbntv.co.kr/news/articleView.html?idxno=926287
# 9 [새로나온책] 플로렌스 나이팅게일의 생애와 업적 외 http://www.joongboo.com/news/articleView.html?idxno=363484903
# ...

# %%
import requests
import openpyxl

client_id = 'v2rU3k_29grolRuMAxIl'
client_secret = 'AvOX6aVmqN'
start, num = 1, 0 

excel_file = openpyxl.Workbook()
excel_sheet = excel_file.active
excel_sheet.column_dimensions['B'].width = 100 
excel_sheet.column_dimensions['C'].width = 100
excel_sheet.append(['랭킹', '제목','링크'])

for index in range(10) :
    start_number = start + (index * 100)
    naver_open_api = 'https://openapi.naver.com/v1/search/news.json?query=삼성&display=100&start=1' + str(start_number)
    header_params = {"X-Naver-Client-Id":client_id, "X-Naver-Client-Secret":client_secret}
    res = requests.get(naver_open_api, headers = header_params)

    if res.status_code == 200 :
        data = res.json()
        for item in data['items'] :
            num += 1
            excel_sheet.append([num, item['title'], item['link']])
    else : 
        print("Error Code:",res.status_code)
        
excel_file.save('IT.xlsx')
excel_file.close()
# Out:
# Error Code: 400
# Error Code: 400
# Error Code: 400
# Error Code: 400
# Error Code: 400
# Error Code: 400
# Error Code: 400
# Error Code: 400
# Error Code: 400

# %%
import requests
open_api = 'http://apis.data.go.kr/B552584/ArpltnInforInqireSvc/getCtprvnRltmMesureDnsty'
serviceKey = '?serviceKey=SfgvhP9am3YBTwKkDW1i9zU45lRVvL%2By8mnIMIbyyZ75i1ibQi%2FGz52qAvyxfYLstKAY%2BYDDD2YTzjj5tAz5hg%3D%3D'
returnType = '&returnType=json'
numOfRows = '&numOfRows=100'
sidoName = '&sidoName=서울'
res = requests.get(open_api+serviceKey+returnType+numOfRows+sidoName)
#print(res.text)
if res.status_code == 200:
    data = res.json()
    print(data['response']['body']['items'])
    # for index, item in enumerate(data['items']):
    #     print (index, item)
else:
    print("Error Code:", res.status_code)
# Out:
# [{'so2Grade': '1', 'coFlag': None, 'khaiValue': '94', 'so2Value': '0.004', 'coValue': '0.5', 'pm10Flag': None, 'o3Grade': '2', 'pm10Value': '97', 'khaiGrade': '2', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'so2Flag': None, 'dataTime': '2021-05-06 16:00', 'coGrade': '1', 'no2Value': '0.021', 'stationName': '중구', 'pm10Grade': '2', 'o3Value': '0.073'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '99', 'so2Value': '0.003', 'coValue': '0.8', 'pm10Flag': None, 'o3Grade': '2', 'pm10Value': '110', 'khaiGrade': '2', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '2', 'o3Flag': None, 'so2Flag': None, 'dataTime': '2021-05-06 16:00', 'coGrade': '1', 'no2Value': '0.033', 'stationName': '한강대로', 'pm10Grade': '2', 'o3Value': '0.036'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '95', 'so2Value': '0.005', 'coValue': '0.5', 'pm10Flag': None, 'o3Grade': '2', 'pm10Value': '96', 'khaiGrade': '2', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'so2Flag'
# ...

# %%
import requests

service_key = 'SfgvhP9am3YBTwKkDW1i9zU45lRVvL%2By8mnIMIbyyZ75i1ibQi%2FGz52qAvyxfYLstKAY%2BYDDD2YTzjj5tAz5hg%3D%3D'
params = '&numOfRows=10&pageNo=1&sidoName=서울'
open_api = 'http://apis.data.go.kr/B552584/ArpltnInforInqireSvc/getCtprvnRltmMesureDnsty?ServiceKey='+service_key + params

res = requests.get(open_api)

print(res.text)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <response>
#   <header>
#     <resultCode>00</resultCode>
#     <resultMsg>NORMAL_CODE</resultMsg>
#   </header>
#   <body>
#     <items>
#       <item>
#         <so2Grade>1</so2Grade>
#         <coFlag/>
#         <khaiValue>94</khaiValue>
#         <so2Value>0.004</so2Value>
#         <coValue>0.5</coValue>
#         <pm10Flag/>
#         <o3Grade>2</o3Grade>
#         <pm10Value>97</pm10Value>
#         <khaiGrade>2</khaiGrade>
#         <sidoName>서울</sidoName>
#         <no2Flag/>
#         <no2Grade>1</no2Grade>
#         <o3Flag/>
#         <so2Flag/>
#         <dataTime>2021-05-06 16:00</dataTime>
#         <coGrade>1</coGrade>
#         <no2Value>0.021</no2Value>
#         <stationName>중구</stationName>
#         <pm10Grade>2</pm10Grade>
#         <o3Value>0.073</o3Value>
#       </item>
#       <item>
#         <so2Grade>1</so2Grade>
#         <coFlag/>
#         <khaiValue>99</khaiValue>
#         <so2Value>0.003</so2Value>
# ...

# %%
from bs4 import BeautifulSoup

service_key = 'SfgvhP9am3YBTwKkDW1i9zU45lRVvL%2By8mnIMIbyyZ75i1ibQi%2FGz52qAvyxfYLstKAY%2BYDDD2YTzjj5tAz5hg%3D%3D'
params = '&numOfRows=10&pageNo=1&sidoName=서울'
open_api = 'http://apis.data.go.kr/B552584/ArpltnInforInqireSvc/getCtprvnRltmMesureDnsty?ServiceKey='+service_key + params
res = requests.get(open_api)
soup = BeautifulSoup(res.content, 'html.parser')

data = soup.find_all('item')
for item in data :
    stationname = item.find('stationname')
    pm10grade = item.find('pm10grade')
    print(stationname.get_text(), pm10grade.get_text())
# Out:
# 중구 2
# 한강대로 2
# 종로구 2
# 청계천로 2
# 종로 2
# 용산구 2
# 광진구 2
# 성동구 2
# 강변북로 2
# 중랑구 2
